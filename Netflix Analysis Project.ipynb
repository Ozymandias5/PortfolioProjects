# %% [markdown]
# # NETFLIX DATA ANALYSIS

# %% [markdown]
# #### Netflix is a streaming service that offers movies, TV shows, and other content. This dataset is a cleaned version of the original version found [here](https://www.kaggle.com/datasets/shivamb/netflix-shows).
# #### The data consists of content added to Netflix from 2008 to 2021. The oldest content is as old as 1925 and the newest as 2021.
# #### This dataset will be cleaned with SQL in Oracle Apex and visualized with Tableau. The purpose of this analysis is to test my data cleaning, analytics, and visualization skills. The process of this project is below.
# #### This project is credited to [ABDULRASAQ ARIYO](https://www.kaggle.com/datasets/ariyoomotade/netflix-data-cleaning-analysis-and-visualization?select=netflix1.csv).
# #### The Tableau dashboard of this project can be found [here](https://public.tableau.com/app/profile/akin1849/viz/NetflixAnalysis_16654634754070/Dashboard1?publish=yes).

# %% [markdown]
# ## Data Cleaning
# To clean this data, these are the things I will do:
# 1. Treat the Nulls
# 2. Treat the duplicates
# 3. Populate missing rows
# 4. Drop columns that are not needed
# 5. Split columns
#
# ### Extra steps and explanation will be explained through the code comments, and I will use pictures to show some queries and their results.
# ### Note: The query results shown in the pictures will be a shortened version of the actual results.

# %%
#Let's view the dataset

# %% [markdown]
# ![netflix%20select.png](attachment:netflix%20select.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# The SHOW_ID column is the unique id for the dataset, therefore we are going to check for duplicates

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# There are no duplicates int the show_id column

# %%
# Now, let's check for null values across columns

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# There are no null values

# %% [markdown]
# # Data Visualization

# %% [markdown]
# #### Note: In the visualization captions, Content means Movies and TV shows, and Content may either mean Movie or TV Show.

# %% [markdown]
# ### Sheet 1: Content type in percantage

# %% [markdown]
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# This first sheet shows the two categories of content in the dataset which are Movie and Tv show.
#
# - As we can see the majority of the content is Movie which make up 69.9%.
#
# - There are more details in the tooltip of the tableau sheet which shows the exact count of Movie and Tv show.

# %% [markdown]
# ### Sheet 2: Amount of Movies & TV Shows by country

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This shows the the total amount of Movies and Tv shows per country within the given period of time(2008 - 2021). This can be noted by the size of the coloured circles in the map.
#
# - We can see that the United State of America has the largest size, followed by India, and the United Kingdom.
#
# - In the Tableau hosted dashboard/sheet, there is a filter for the years between 2008 and 2021 to calculate yearly records.
#
# To give an alternate and clearer view, The bar chart of Movie & TV shows by country is shown below:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Sheet 3. Number of Content Added through the Years:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This time series chart shows the total number of content added to Netflix through the given years (2008 - 2021)

# %% [markdown]
# - It shows that most movies and tv shows on Netflix were added in 2019
# - In the Tableau sheet, there is a filter to know how many Movies and Tv shows were added in each month of the years

# %% [markdown]
# ### Sheet 4. Top Directors:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# This chart shows the top 10 directors with most content on Netflix. This chart shows the count of Movies and Tv shows in their catalouge.
#
# - We can see that most of these directors' content are movies.
# - We can also note that the duo of Raul Campos and Jan Suter are fond of working together and have directed 18 movies on Netflix.

# %% [markdown]
# ### Sheet 5. Top Genres:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This chart shows the number of movies allocated to particular genres on Netflix.
#
# We can see that Drama & International movies followed by Documentary have the highest number of content on Netflix within the given period.

# %% [markdown]
# ### Sheet 6. Top Ratings:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Rating is a system to rate a motion picture's suitability for certain audiences based on its content. This chart shows the top ratings on Netflix
# - We can note that most contents on Netflix are rated TV-MA. TV-MA in the United States by the TV Parental Guidelines signifies content for mature audiences.

# %% [markdown]
# ### Sheet 7. Oldest Contents on Netflix by Content Release year:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This table shows the 10 oldest movies and tv shows on Netflix
#
# The oldest is from 1925

# %% [markdown]
# ### Sheet 8. Content Types over the Years:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This line chart compares the Movie and Tv shows contents added to Netflix through the years.
#
# - We can see that more movies have always been added.
# - In 2013, the number of contents added to Netflix for both were almost the same with Movies having 6 contents that year and Tv shows having 5.
# - It shows that in the first 5 years, only movies were added to Netflix.

# %% [markdown]
# ### Sheet 9. Release Years with Highest Contents:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This chart shows the Movies and Tv shows production years which have the highest contents on Netflix. We focus on the top 10 release years with the highest number of contents.
# - We can see that from 2012 to 2018, Netflix added most contents, they made sure contents per release year were higher than those of the older release years. Then in 2019, the numbe of contents added started dropping, this may be due to the Covid-19, but further analysis may be needed to determine this.
#
# This is the end of the exercise. The dashboard for this project can be found [here](https://public.tableau.com/app/profile/akin1849/viz/NetflixAnalysis_16654634754070/Dashboard1?publish=yes).
